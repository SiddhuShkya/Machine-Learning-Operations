# %%
# !python --version
# Out:
# Python 3.12.3

# %% [markdown]
# ### `MLFlow Tracking Server`

# %%
import mlflow 

mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Check localhost connection")

with mlflow.start_run():
    mlflow.log_metric("test", 1)
    mlflow.log_metric("Siddhu", 2)
# Out:
# 2025/12/09 16:21:59 INFO mlflow.tracking.fluent: Experiment with name 'Check localhost connection' does not exist. Creating a new experiment.
# 🏃 View run righteous-rook-275 at: http://127.0.0.1:5000/#/experiments/1/runs/7fe2191c1b4d4e41a1027f47b5874a16
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test", 1)
    mlflow.log_metric("Siddhu", 2)
# Out:
# 🏃 View run overjoyed-sow-967 at: http://127.0.0.1:5000/#/experiments/1/runs/e17b1d3adb3f404fa6c7bbc99bf9a44a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test2", 1)
    mlflow.log_metric("Siddhu2", 2)
# Out:
# 🏃 View run bouncy-colt-568 at: http://127.0.0.1:5000/#/experiments/1/runs/8f2f56c01f284b91aceab2f79666967a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
